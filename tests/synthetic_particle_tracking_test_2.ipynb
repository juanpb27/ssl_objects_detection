# %% [markdown]
# # Synthetic Particle Tracking - Test 2
# -----------------
# This code is obtained from DeepTrack2 library notebooks: https://github.com/softmatterlab/DeepTrack2
#
# **Adapted by:** Eberto Benjumea and Juan C. Peña

# %%
# %matplotlib inline
# !pip install deeptrack

# %% [markdown]
# <!--<badge>--><a href="https://colab.research.google.com/github/softmatterlab/DeepTrack-2.0/blob/master/examples/LodeSTAR/03.track_BF-C2DL-HSC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a><!--</badge>-->

# %%
import deeptrack as dt
import numpy as np
import skimage.color
import matplotlib.pyplot as plt
import cv2

# %%
# find frequency of pixels in range 0-255
training_image = dt.LoadImage(f"sintetica.png")()._value 
#training_image  = cv2.cvtColor(training_image , cv2.COLOR_BGR2RGB)
plt.imshow(training_image)
plt.axis("off")

name_comp=['Blue','Red','Green']
for i in range(0,3):
  histr = cv2.calcHist([training_image],[i],None,[256],[0,256])
  #print(i)
  # show the plotting graph of an image
  plt.figure()
  plt.plot(histr)
  plt.ylabel('Counts')
  plt.xlabel('Pixels value')
  plt.title(name_comp[i]+' component')
  plt.show()

# %%
training_image
# Out:
# array([[[252,   0,   0, 248],
#         [252,   0,   0, 248],
#         [252,   0,   0, 248],
#         ...,
#         [252,   0,   0, 248],
#         [252,   0,   0, 248],
#         [252,   0,   0, 248]],
#
#        [[252,   0,   0, 248],
#         [236,   0,   0, 248],
#         [192,   0,   0, 248],
#         ...,
#         [192,   0,   0, 248],
#         [236,   0,   0, 248],
#         [252,   0,   0, 248]],
#
#        [[252,   0,   0, 248],
#         [192,   0,   0, 248],
#         [  0,   0,   0, 248],
#         ...,
#         [  0,   0,   0, 248],
#         [192,   0,   0, 248],
#         [252,   0,   0, 248]],
#
#        ...,
#
#        [[252,   0,   0, 248],
#         [192,   0,   0, 248],
#         [  0,   0,   0, 248],
#         ...,
#         [  0,   0,   0, 248],
#         [192,   0,   0, 248],
#         [252,   0,   0, 248]],
#
#        [[252,   0,   0, 248],
#         [236,   0,   0, 248],
#         [192,   0,   0, 248],
#         ...,
#         [192,   0,   0, 248],
#         [236,   0,   0, 248],
#         [252,   0,   0, 248]],
#
#        [[252,   0,   0, 248],
#         [252,   0,   0, 248],
#         [252,   0,   0, 248],
#         ...,
#         [252,   0,   0, 248],
#         [252,   0,   0, 248],
#         [252,   0,   0, 248]]], dtype=uint8)

# %%
training_image = dt.LoadImage(f"sintetica.png")()._value 
training_image  = cv2.cvtColor(training_image , cv2.COLOR_BGR2RGB)/ 256
#training_image = 0.21*training_image[:,:,0] + 0.72*training_image[:,:,1]+ 0.07*training_image[:,:,2]
training_image = 0.2989*training_image[:,:,0] + 0.5870*training_image[:,:,1]+ 0.1140*training_image[:,:,2]

training_image  = cv2.resize(training_image, (0, 0), fx=0.3, fy=0.3)
plt.imshow(training_image)
plt.axis("off")
# Out:
# (-0.5, 217.5, 158.5, -0.5)

# %%
training_image.shape
# Out:
# (159, 218)

# %%
t, x, y, w = (251, 100, 0, 39)
crop = training_image[y:y+w, x:x+w]
plt.imshow(crop)
plt.axis("off")
print(crop.shape)
# Out:
# (39, 39)

# %%
print(crop.shape)
crop = np.expand_dims(crop, axis = 2)
# Out:
# (39, 39)

# %%
model = dt.models.LodeSTAR(input_shape=(None, None, 1))

train_set =   (
    dt.Value(crop)
    >> dt.Add(lambda: np.random.randn() * 0.1)
    >> dt.Gaussian(sigma=lambda:np.random.uniform(0, 0.2))  
    >> dt.Multiply(lambda: np.random.uniform(0.6, 1.2))
)
# model.model.consistency_weight = X
model.fit(
    train_set,
    epochs=100,
    batch_size=8,
)
# Out:
# Generating 162 / 160 samples before starting training
# Epoch 1/100
# 162/162 [==============================] - 10s 13ms/step - total_loss: 1.5532 - consistency_loss: 0.7291
# Epoch 2/100
# 162/162 [==============================] - 2s 11ms/step - total_loss: 0.8442 - consistency_loss: 0.4150
# Epoch 3/100
# 162/162 [==============================] - 2s 14ms/step - total_loss: 0.1978 - consistency_loss: 0.0551
# Epoch 4/100
# 162/162 [==============================] - 2s 14ms/step - total_loss: 0.1805 - consistency_loss: 0.0504
# Epoch 5/100
# 162/162 [==============================] - 2s 13ms/step - total_loss: 0.0920 - consistency_loss: 0.0144
# Epoch 6/100
# 162/162 [==============================] - 2s 15ms/step - total_loss: 0.0919 - consistency_loss: 0.0124
# Epoch 7/100
# 162/162 [==============================] - 2s 15ms/step - total_loss: 0.0691 - consistency_loss: 0.0099
# Epoch 8/100
# 162/162 [==============================] - 2s 13ms/step - total_loss: 0.0697 - consistency_loss: 0.0105
# Epoch 9/100
# 162/162 [==============================] - 2s 13ms/step - total_loss: 0.0587 - consistency_loss: 0.0085
# Epoch 10/100
# 162/162 [==============================] - 2s 15ms/step - total_loss: 0.0577 - consistency_loss: 0.0087
# Epoch 11/100
# 162/162 [==============================] - 3s 21ms/step - total_loss: 0.0654 - consistency_loss: 0.0100
# Epoch 12/100
# 162/162 [==============================] - 2s 13ms/step - total_loss: 0.0694 - consistency_loss: 0.0093
# Epoch 13/100
# 162/162 [==============================] - 3s 16ms/step - total_loss: 0.0564 - consistency_loss: 0.0090
# Epoch 14/100
# 162/162 [==============================] - 2s 14ms/step - total_loss: 0.0487 - consistency_loss: 0.0082
# Epoch 15/100
# 162/162 [==============================] - 2s 13ms/step - total_loss: 0.0576 - consistency_loss: 0.0094
# Epoch 16/100
# 162/162 [==============================] - 2s 14ms/step - total_loss: 0.0567 - consistency_loss: 0.0079
# Epoch 17/100
# 162/162 [==============================] - 2s 13ms/step - total_loss: 0.0569 - consistency_loss: 0.0080
# Epoch 18/100
# 162/162 [==============================] - 2s 13ms/step - total_loss: 0.0577 - consistency_loss: 0.0082
# Epoch 19/100
# 162/162 [==============================] - 2s 13ms/step - total_loss: 0.0427 - consistency_loss: 0.0066
# Epoch 20/100
# 162/162 [==============================] - 2s 14ms/step - total_loss: 0.0466 - consistency_loss: 0.0067
# Epoch 21/100
# 162/162 [==============================] - 2s 13ms/step - total_loss: 0.0502 - consistency_loss: 0.0066
# Epoch 22/100
# 162/162 [==============================] - 2s 13ms/step - total_loss: 0.0493 - consistency_loss: 0.0069
# Epoch 23/100
# 162/162 [==============================] - 2s 13ms/step - total_loss: 0.0428 - consistency_loss: 0.0072
# Epoch 24/100
# 162/162 [==============================] - 2s 13ms/step - total_loss: 0.0482 - consistency_loss: 0.0067
# Epoch 25/100
# 162/162 [==============================] - 2s 13ms/step - total_loss: 0.0440 - consistency_loss: 0.0064
# Epoch 26/100
# 162/162 [==============================] - 2s 13ms/step - total_loss: 0.0415 - consistency_loss: 0.0064
# Epoch 27/100
# 162/162 [==============================] - 2s 13ms/step - total_loss: 0.0388 - consistency_loss: 0.0060
# Epoch 28/100
# 162/162 [==============================] - 2s 13ms/step - total_loss: 0.0461 - consistency_loss: 0.0064
# Epoch 29/100
# 162/162 [==============================] - 2s 13ms/step - total_loss: 0.0369 - consistency_loss: 0.0059
# Epoch 30/100
# 162/162 [==============================] - 2s 13ms/step - total_loss: 0.0422 - consistency_loss: 0.0065
# Epoch 31/100
# 162/162 [==============================] - 2s 12ms/step - total_loss: 0.0375 - consistency_loss: 0.0056
# Epoch 32/100
# 162/162 [==============================] - 2s 13ms/step - total_loss: 0.0412 - consistency_loss: 0.0056
# Epoch 33/100
# 162/162 [==============================] - 2s 13ms/step - total_loss: 0.0446 - consistency_loss: 0.0057
# Epoch 34/100
# 162/162 [==============================] - 2s 14ms/step - total_loss: 0.0472 - consistency_loss: 0.0053
# Epoch 35/100
# 162/162 [==============================] - 2s 13ms/step - total_loss: 0.0354 - consistency_loss: 0.0050
# Epoch 36/100
# 162/162 [==============================] - 2s 12ms/step - total_loss: 0.0361 - consistency_loss: 0.0058
# Epoch 37/100
# 162/162 [==============================] - 2s 12ms/step - total_loss: 0.0376 - consistency_loss: 0.0053
# Epoch 38/100
# 162/162 [==============================] - 2s 13ms/step - total_loss: 0.0405 - consistency_loss: 0.0048
# Epoch 39/100
# 162/162 [==============================] - 2s 12ms/step - total_loss: 0.0316 - consistency_loss: 0.0047
# Epoch 40/100
# 162/162 [==============================] - 2s 12ms/step - total_loss: 0.0395 - consistency_loss: 0.0048
# Epoch 41/100
# 162/162 [==============================] - 2s 13ms/step - total_loss: 0.0381 - consistency_loss: 0.0045
# Epoch 42/100
# 162/162 [==============================] - 2s 13ms/step - total_loss: 0.0379 - consistency_loss: 0.0053
# Epoch 43/100
# 162/162 [==============================] - 2s 14ms/step - total_loss: 0.0350 - consistency_loss: 0.0042
# Epoch 44/100
# 162/162 [==============================] - 2s 14ms/step - total_loss: 0.0323 - consistency_loss: 0.0047
# Epoch 45/100
# 162/162 [==============================] - 2s 14ms/step - total_loss: 0.0358 - consistency_loss: 0.0043
# Epoch 46/100
# 162/162 [==============================] - 2s 12ms/step - total_loss: 0.0316 - consistency_loss: 0.0039
# Epoch 47/100
# 162/162 [==============================] - 2s 11ms/step - total_loss: 0.0349 - consistency_loss: 0.0044
# Epoch 48/100
# 162/162 [==============================] - 2s 14ms/step - total_loss: 0.0325 - consistency_loss: 0.0044
# Epoch 49/100
# 162/162 [==============================] - 2s 13ms/step - total_loss: 0.0370 - consistency_loss: 0.0045
# Epoch 50/100
# 162/162 [==============================] - 2s 13ms/step - total_loss: 0.0320 - consistency_loss: 0.0040
# Epoch 51/100
# 162/162 [==============================] - 2s 13ms/step - total_loss: 0.0314 - consistency_loss: 0.0038
# Epoch 52/100
# 162/162 [==============================] - 2s 14ms/step - total_loss: 0.0370 - consistency_loss: 0.0040
# Epoch 53/100
# 162/162 [==============================] - 2s 13ms/step - total_loss: 0.0308 - consistency_loss: 0.0041
# Epoch 54/100
# 162/162 [==============================] - 2s 13ms/step - total_loss: 0.0337 - consistency_loss: 0.0040
# Epoch 55/100
# 162/162 [==============================] - 2s 14ms/step - total_loss: 0.0305 - consistency_loss: 0.0037
# Epoch 56/100
# 162/162 [==============================] - 2s 12ms/step - total_loss: 0.0321 - consistency_loss: 0.0040
# Epoch 57/100
# 162/162 [==============================] - 2s 14ms/step - total_loss: 0.0385 - consistency_loss: 0.0041
# Epoch 58/100
# 162/162 [==============================] - 2s 15ms/step - total_loss: 0.0330 - consistency_loss: 0.0036
# Epoch 59/100
# 162/162 [==============================] - 3s 16ms/step - total_loss: 0.0295 - consistency_loss: 0.0033
# Epoch 60/100
# 162/162 [==============================] - 2s 15ms/step - total_loss: 0.0325 - consistency_loss: 0.0034
# Epoch 61/100
# 162/162 [==============================] - 2s 15ms/step - total_loss: 0.0306 - consistency_loss: 0.0034
# Epoch 62/100
# 162/162 [==============================] - 2s 14ms/step - total_loss: 0.0291 - consistency_loss: 0.0033
# Epoch 63/100
# 162/162 [==============================] - 3s 16ms/step - total_loss: 0.0314 - consistency_loss: 0.0032
# Epoch 64/100
# 162/162 [==============================] - 2s 13ms/step - total_loss: 0.0372 - consistency_loss: 0.0039
# Epoch 65/100
# 162/162 [==============================] - 2s 12ms/step - total_loss: 0.0311 - consistency_loss: 0.0034
# Epoch 66/100
# 162/162 [==============================] - 2s 15ms/step - total_loss: 0.0266 - consistency_loss: 0.0032
# Epoch 67/100
# 162/162 [==============================] - 2s 14ms/step - total_loss: 0.0304 - consistency_loss: 0.0033
# Epoch 68/100
# 162/162 [==============================] - 2s 13ms/step - total_loss: 0.0298 - consistency_loss: 0.0032
# Epoch 69/100
# 162/162 [==============================] - 2s 13ms/step - total_loss: 0.0287 - consistency_loss: 0.0032
# Epoch 70/100
# 162/162 [==============================] - 2s 13ms/step - total_loss: 0.0296 - consistency_loss: 0.0032
# Epoch 71/100
# 162/162 [==============================] - 1s 9ms/step - total_loss: 0.0319 - consistency_loss: 0.0031
# Epoch 72/100
# 162/162 [==============================] - 2s 12ms/step - total_loss: 0.0376 - consistency_loss: 0.0033
# Epoch 73/100
# 162/162 [==============================] - 2s 13ms/step - total_loss: 0.0329 - consistency_loss: 0.0032
# Epoch 74/100
# 162/162 [==============================] - 2s 13ms/step - total_loss: 0.0302 - consistency_loss: 0.0030
# Epoch 75/100
# 162/162 [==============================] - 2s 13ms/step - total_loss: 0.0279 - consistency_loss: 0.0028
# Epoch 76/100
# 162/162 [==============================] - 2s 14ms/step - total_loss: 0.0250 - consistency_loss: 0.0028
# Epoch 77/100
# 162/162 [==============================] - 2s 13ms/step - total_loss: 0.0279 - consistency_loss: 0.0028
# Epoch 78/100
# 162/162 [==============================] - 3s 19ms/step - total_loss: 0.0281 - consistency_loss: 0.0029
# Epoch 79/100
# 162/162 [==============================] - 3s 15ms/step - total_loss: 0.0275 - consistency_loss: 0.0027
# Epoch 80/100
# 162/162 [==============================] - 2s 14ms/step - total_loss: 0.0250 - consistency_loss: 0.0028
# Epoch 81/100
# 162/162 [==============================] - 2s 14ms/step - total_loss: 0.0267 - consistency_loss: 0.0029
# Epoch 82/100
# 162/162 [==============================] - 2s 13ms/step - total_loss: 0.0289 - consistency_loss: 0.0030
# Epoch 83/100
# 162/162 [==============================] - 2s 14ms/step - total_loss: 0.0253 - consistency_loss: 0.0027
# Epoch 84/100
# 162/162 [==============================] - 2s 14ms/step - total_loss: 0.0288 - consistency_loss: 0.0027
# Epoch 85/100
# 162/162 [==============================] - 2s 14ms/step - total_loss: 0.0241 - consistency_loss: 0.0025
# Epoch 86/100
# 162/162 [==============================] - 2s 14ms/step - total_loss: 0.0302 - consistency_loss: 0.0035
# Epoch 87/100
# 162/162 [==============================] - 2s 14ms/step - total_loss: 0.0291 - consistency_loss: 0.0029
# Epoch 88/100
# 162/162 [==============================] - 2s 13ms/step - total_loss: 0.0257 - consistency_loss: 0.0027
# Epoch 89/100
# 162/162 [==============================] - 2s 14ms/step - total_loss: 0.0246 - consistency_loss: 0.0027
# Epoch 90/100
# 162/162 [==============================] - 2s 14ms/step - total_loss: 0.0252 - consistency_loss: 0.0024
# Epoch 91/100
# 162/162 [==============================] - 2s 13ms/step - total_loss: 0.0266 - consistency_loss: 0.0025
# Epoch 92/100
# 162/162 [==============================] - 2s 14ms/step - total_loss: 0.0273 - consistency_loss: 0.0025
# Epoch 93/100
# 162/162 [==============================] - 2s 13ms/step - total_loss: 0.0250 - consistency_loss: 0.0023
# Epoch 94/100
# 162/162 [==============================] - 2s 14ms/step - total_loss: 0.0262 - consistency_loss: 0.0024
# Epoch 95/100
# 162/162 [==============================] - 2s 15ms/step - total_loss: 0.0280 - consistency_loss: 0.0025
# Epoch 96/100
# 162/162 [==============================] - 2s 14ms/step - total_loss: 0.0270 - consistency_loss: 0.0025
# Epoch 97/100
# 162/162 [==============================] - 2s 14ms/step - total_loss: 0.0275 - consistency_loss: 0.0026
# Epoch 98/100
# 162/162 [==============================] - 2s 14ms/step - total_loss: 0.0261 - consistency_loss: 0.0025
# Epoch 99/100
# 162/162 [==============================] - 2s 14ms/step - total_loss: 0.0268 - consistency_loss: 0.0025
# Epoch 100/100
# 162/162 [==============================] - 2s 14ms/step - total_loss: 0.0283 - consistency_loss: 0.0023

# %%
#May need to tune these to get optimal performance!
alpha = 0.2
cutoff = 0.99

frame_index = 1763


training_image = dt.LoadImage(f"sintetica.png")()._value / 256
training_image = 0.21*training_image[:,:,0] + 0.72*training_image[:,:,1]+ 0.07*training_image[:,:,2]

image  = cv2.resize(training_image, (0, 0), fx=0.3, fy=0.3)
#image = np.expand_dims(image, axis = 2)


#image = dt.LoadImage(f"data/BF-C2DL-HSC/t{frame_index:04d}.tif")()._value / 256
#image = image[130:-130, :400]

detections = model.predict_and_detect(image[np.newaxis], alpha=alpha, beta=1-alpha, cutoff=cutoff, mode="quantile")[0]
# detections = autotracker.detect(pred[0], weights[0], beta=1-alpha, alpha=alpha, cutoff=cutoff, mode="constant")

plt.figure(figsize=(15, 15))
plt.imshow(image)
plt.axis("off")
plt.scatter(detections[:, 1], detections[:, 0], color="r")
